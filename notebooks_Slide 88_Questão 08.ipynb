# %% [markdown]
# ___
# # <center> Questão 08: Demonstração da Operação de Leitura

# %%
from PIL import Image 
Image.open("Image_Diagrama.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=271x802>

# %% [markdown]
# ##### <center> Demonstração geral do diagrama
# ___

# %%
Image.open("Image_Instrução.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=396x400>

# %% [markdown]
# ##### <center> 1. O REM recebe determinado endereço de outro registrador, e transporta esse endereço via barramento(BE) para a MP.
# ##### <center> 2. A Unidade de controle determina que a operação será de leitura e envia essa instrução para a memória por seu respectivo barramento.

# %%
Image.open("Image_Decodificação.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=393x332>

# %% [markdown]
# ##### <center> 3. O Controlador da Memória recebe o sinal de leitura e verifica se a memória está preparada para efetuar a instrução
# ##### <center> 4. Caso a resposta seja sim, o controlador decodifica o endereço e localiza a célula que será utilizada. Se a resposta for não, ele irá verificar o estado novamente.

# %%
Image.open("Image_Leitura.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=385x550>

# %% [markdown]
# ##### <center> 5. Após a localização da célula desejada, o dado contido é enviado para o processador pelo barramento de dados.
# ##### <center> 6. O barramento fornece o conteúdo para o RDM e completa a instrução de leitura.
# ##### <center> 7. Caso a operação esteja encerrada, o sistema irá se preparar para a próxima. Caso contrário, a UC solicita uma nova leitura.
# ___

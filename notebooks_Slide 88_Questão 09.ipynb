# %% [markdown]
# ___
# # <center> Questão 09: Demonstração da Operação de Escrita

# %%
from PIL import Image
Image.open("Image_DiagramaE.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=282x801>

# %% [markdown]
# ##### <center> Demonstração geral do diagrama
# ___

# %%
Image.open("Image_Instrucao.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=376x407>

# %% [markdown]
# ##### <center> 1. Outros registradores enviam a informação e o endereço que serão utilizados, e o RDM e REM repassam para seus respectivos barramentos.
# ##### <center> 2. A unidade de controle determina que será feita uma operação de escrita e envia a instrução pelo barramento(BC)

# %%
Image.open("Image_Decodificacao.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=412x468>

# %% [markdown]
# ##### <center> 3. O controlador verifica se a memória está preparada para realizar a instrução de escrita.
# ##### <center> 4. Caso a resposta seja sim, o controlador decodifica o endereço. Do contrário, ele irá verificar o estado novamente.
# ##### <center> 5. Com a decodificação realizada, o controlador localiza a célula na MP e a prepara para a escrita.

# %%
Image.open("Image_Escrita.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=393x389>

# %% [markdown]
# ##### <center> 6. Com a célula localizada, o BD envia os dados que serão escritos na célula para a MP e realiza a operação.
# ##### <center> 7. Caso seja o fim da operação, o sistema se prepara para uma nova instrução. Se a operação ainda não foi encerrada, a UC solicita uma nova escrita.
# ___

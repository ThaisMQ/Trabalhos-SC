# %% [markdown]
# ___
# # <center> Questão 26

# %%
from PIL import Image 
Image.open("Image_Comando.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=863x68>

# %% [markdown]
# ___
# # <center> Circuito:

# %%
Image.open("Image_Circuito.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=400x597>

# %% [markdown]
# ##### <center> Memória ROM de 8 células com capacidade de armazenamento de 4 bits </center> #####
#
# <center> Para compor uma memória ROM de 8 células, são necessárias três entradas de endereçamento, pois é seguida a lógica:
#
# ##### <center> 2^3 = 8
#
# <center> O resultado compreende a quantidade de células desejadas.
#
# <center> As portas AND compreendem o decodificador, que identifica as células desejadas e transmitem o resultado para a saída.
#
# ___
#
# # <center> Conteúdo da ROM: #

# %%
Image.open("Image_ROM.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=166x164>

# %% [markdown]
# ##### <center> Relação entre o endereço e o conteúdo retornado na ROM.
#
# ___
